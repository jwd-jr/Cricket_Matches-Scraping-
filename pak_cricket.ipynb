# %%
import requests
from bs4 import BeautifulSoup

# %%
icc=requests.get("https://www.google.com/search?q=icc+live+score&rlz=1C1GCEU_enPK1161PK1161&oq=icc&gs_lcrp=EgZjaHJvbWUqDggBEEUYJxg7GIAEGIoFMgYIABBFGDwyDggBEEUYJxg7GIAEGIoFMg8IAhAuGEMYyQMYgAQYigUyDAgDEC4YQxiABBiKBTIOCAQQRRgnGDsYgAQYigUyDAgFEAAYQxiABBiKBTIMCAYQABhDGIAEGIoFMgYIBxBFGDzSAQgyNTczajBqN6gCALACAA&sourceid=chrome&ie=UTF-8#sie=t;/m/038_0z;5;/m/021q23;mt;fp;1;;;")
print(icc)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(icc.text, 'lxml')

# %%
team =soup.find_all("div",class_="liveresults-sports-immersive__hide-element")
print(team)
# Out:
# []
